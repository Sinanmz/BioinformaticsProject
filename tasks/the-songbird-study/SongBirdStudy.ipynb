# %% [markdown]
# # Final Project of Introduction to Bioinformatics
#
# ## The Song Bird Study

# %% [markdown]
# <div style="text-align: center;">
#     <img src="SocialNetworking.png" width="350">
# </div>

# %% [markdown]
# ### Introduction
#
# #### Investigating the Influence of Social Environment on Neural Responses to Sickness in Zebra Finches: A Bioinformatics Approach
#
# The Zebra Finch, _Taeniopygia guttata_, a widely used model organism in behavioral and neurobiological research, provides an excellent platform to study the interplay between social environment, neural function, and immune response. In this project, we delve into an intriguing scientific question: How does the social environment of these birds modulate their neural response to immune challenges?
#
# This question was explored in a study by Lopes PC, Faber-Hammond JJ, Siemonsma C, Patel S, and Renn SCP, titled _"The social environment alters neural responses to a lipopolysaccharide challenge"_ (Brain Behav Immun 2023). Their research demonstrated that the social environment, particularly the presence of conspecifics, could significantly modulate the neural responses of Zebra Finches to immune challenges such as lipopolysaccharide (LPS), a molecule known to induce immune responses. Link to Paper
#
# Our goal in this notebook is to revisit and build upon the findings of this study. Using RNA sequencing data from their research, we aim to conduct a comprehensive analysis of changes in gene expression across different brain regions of Zebra Finches under different social conditions. We will specifically focus on the hypothalamus, the bed nucleus of the stria terminalis, and the nucleus taeniae, all of which are key regions for understanding behavior and immune response.
#
# The essence of this project is to draw meaningful insights from high-dimensional data. We encourage you to start with basic approaches and gradually build complexity. Remember, every effort to extract information and gain insights from the data is valuable and will be recognized. Approach the tasks with curiosity and an open mind, and let your analytical journey be both informative and enjoyable.
#
# ---

# %% [markdown]
# ### Experiment Design
#
# The primary aim of this high-throughput sequencing study was to discern how different social environments could modulate the neural response to sickness induced by lipopolysaccharide (LPS).
#
# **Lipopolysaccharide (LPS)** is a large molecule consisting of a lipid and a polysaccharide, found in the outer membrane of Gram-negative bacteria. It is often referred to as an endotoxin due to its ability to trigger strong immune responses. When a Gram-negative bacterium dies, it releases its LPS, which can then find its way into the bloodstream. In the context of this study, LPS was used to simulate an immune challenge or sickness in the Zebra Finches.
#
# **The Experimental Setup:**
#
# The experiment involved male Zebra Finches, which were administered either an LPS injection to simulate sickness or a control solution. Following the injection, the birds were placed in one of four distinct social contexts:
#
# - **Isolated (ISO)**: In this setting, the birds were kept alone without a female. This condition was designed to examine the neural and immune responses of the birds in the absence of any social interactions. This group helps to understand the baseline responses to the LPS challenge when there are no social factors at play.
# - **Known Female Continuous (KFC)**: Here, the birds were continuously housed with a known female. This condition allowed the researchers to investigate the effects of a stable social environment on the birds' responses to the LPS challenge. This group can provide insights into how ongoing social interactions might influence the response to sickness.
# - **Known Female Reunited (KF)**: In this scenario, the birds were reunited with a known female after a period of separation. This condition was intended to mimic the effects of a disrupted social environment followed by a reunion. This group can shed light on how changes in social relationships might affect the neural and immune responses to sickness.
# - **Novel Female (NF)**: In this context, the birds were paired with a previously unknown female. This condition was designed to explore the effects of introducing a new social partner on the birds' responses to the LPS challenge. This group can reveal how novel social encounters might modulate the response to sickness.
#
# These social settings were carefully chosen to represent a range of social interactions that the birds might encounter in their natural habitats. The experimental design allows for a comprehensive investigation of how social environment influences the neural responses to sickness, thereby improving our understanding of how the social environment can affect health.
#
# ---

# %% [markdown]
# ### Understanding RNA-Seq
#
# RNA-Seq (RNA sequencing) is a powerful technique that uses next-generation sequencing (NGS) to reveal the presence and quantity of RNA molecules in a biological sample. It provides a snapshot of gene expression, also known as the transcriptome.
#
# **What is RNA-Seq?**
#
# RNA-Seq allows us to investigate and discover the transcriptome, which is the total cellular content of RNAs including mRNA, rRNA, and tRNA. Understanding the transcriptome is key if we are to connect the information in our genome with its functional protein expression. RNA-Seq can tell us which genes are turned on in a cell, what their level of transcription is, and at what times they are activated or shut off. This allows scientists to understand the biology of a cell more deeply and assess changes that may indicate disease.
#
# **How does RNA-Seq work?**
#
# The RNA-Seq workflow has several steps:
#
# 1. **RNA extraction**: The first step involves extracting the total RNA from the sample.
# 2. **Reverse transcription into cDNA**: The extracted RNA is then converted into complementary DNA (cDNA) through a process called reverse transcription.
# 3. **Library preparation**: The cDNA is then used to prepare a sequencing library. This involves fragmenting the cDNA, adding sequencing adapters, and amplifying the library.
# 4. **Sequencing**: The prepared library is then sequenced using high-throughput sequencing technology.
#
# **RNA-Seq Data**
#
# The output of an RNA-Seq experiment is a large set of short DNA sequences, or reads. These reads can be aligned to a reference genome to determine which genes were being transcribed at the time the sample was collected. The number of reads aligning to a particular gene provides a measure of that gene's expression level.
#
# **RNA-Seq vs Microarrays**
#
# RNA-Seq has several advantages over microarray technology, a legacy technology often used in gene expression studies. Unlike microarrays, which require species- or transcript-specific probes, RNA-Seq does not require any prior knowledge about the sequences of the transcripts. This allows RNA-Seq to detect novel transcripts, gene fusions, single nucleotide variants, indels (small insertions and deletions), and other previously unknown changes. RNA-Seq also has a wider dynamic range and higher sensitivity compared to microarrays, making it better at detecting transcripts and specifically isoforms.
#
# <blockquote style="font-family:Arial; color:red; font-size:16px; border-left:0px solid red; padding: 10px;">
#     <strong>Don't forget to answer these questions!</strong>
# </blockquote>
#
# **Questions**
#
# 1. Why is it important to convert RNA into cDNA for RNA-Seq? What would happen if we tried to sequence RNA directly?
# 2. How does the process of preparing a sequencing library contribute to the accuracy of RNA-Seq results? What are some potential sources of error in this step?
# 3. How does the ability of RNA-Seq to detect novel transcripts contribute to our understanding of gene function? Can you think of a scenario where this capability would be particularly useful?
# 4. Why might a researcher choose to use RNA-Seq instead of microarrays for a gene expression study? What are some potential advantages and disadvantages of each method?
#
#
# **_Your Answer:_**:
#
# 1. Converting RNA into cDNA for RNA-Seq is important because cDNA is more stable and amplifiable than RNA. If we tried to sequence RNA directly, it would be prone to degradation, leading to inaccurate and unreliable results in RNA-Seq analysis.
#
# 2. Preparing a sequencing library accurately ensures that the RNA molecules are faithfully represented in the subsequent sequencing process. This representative sampling helps in obtaining a more precise and reliable depiction of the original RNA composition, improving the accuracy of RNA-Seq results. Errors in library preparation, such as bias or artifacts, can distort the representation and introduce inaccuracies. Contamination can also compromise the fidelity of the sequencing data.
#
# 3. RNA-Seq's ability to detect novel transcripts enhances our understanding of gene function by uncovering previously unknown or uncharacterized transcripts. This capability is particularly useful in scenarios where researchers are exploring complex biological processes, studying diseases, or investigating specific tissues.
#
# For example, consider a study focused on understanding the molecular mechanisms underlying a rare disease. Traditional knowledge about the disease might be limited, and relying solely on existing gene annotations (as in microarrays) could miss crucial information. RNA-Seq's capacity to identify novel transcripts allows researchers to discover new genes, alternative splicing events, and non-coding RNAs that could play important roles in the disease. This comprehensive view contributes significantly to unraveling the intricacies of gene function in various biological contexts.
#
# 4. A researcher might choose RNA-Seq over microarrays for a gene expression study due to RNA-Seq's higher sensitivity, ability to detect novel transcripts, and independence from pre-existing annotations. RNA-Seq provides a more comprehensive and accurate view of the transcriptome, allowing for precise quantification and the identification of new genes and splice variants. In contrast, microarrays may have limitations in sensitivity and are dependent on predefined probes, potentially missing important transcripts and offering less flexibility in experimental design.
#
#
# Here are some of the advantages and disadvantages for each of the methods:
#
#
# Advantages of RNA-Seq:
# 1. Higher Sensitivity: Detects low-abundance transcripts with a broad dynamic range.
# 2. Detection of Novel Transcripts: Identifies new genes, splice variants, and non-coding RNAs.
# 3. Quantification Accuracy: Precisely quantifies gene expression levels.
# 4. No Dependency on Pre-existing Annotations: Suitable for poorly annotated genomes.
#
# Disadvantages of RNA-Seq:
# 1. Higher Cost: Can be expensive, especially for large-scale studies.
# 2. Computational Complexity: Requires more computational resources and expertise.
# 3. Sample Preparation Sensitivity: Sensitive to RNA quality.
#
# Advantages of Microarrays:
# 1. Lower Cost: More cost-effective, suitable for budget constraints.
# 2. Established Technology: Well-established protocols, accessible to researchers.
#
# Disadvantages of Microarrays
# 1. Limited Dynamic Range: May have a restricted dynamic range, especially for low-abundance transcripts.
# 2. Dependency on Probe Design: Relies on predetermined probes, limiting detection of novel transcripts.
# 3. Cross-Hybridization Issues: Potential inaccuracies due to cross-hybridization.
#
# ---

# %% [markdown]
# ### Step 0: Installing Necessary Packages

# %%
import sys
import subprocess
import pkg_resources

def install(package):
    subprocess.check_call([sys.executable, "-m", "pip", "install", package])

REQUIRED_PACKAGES = [
    'biopython',
    'pandas',
    'numpy',
    'matplotlib',
    'seaborn',
    'xlrd',
    'mygene'
]

for package in REQUIRED_PACKAGES:
    try:
        dist = pkg_resources.get_distribution(package)
        print('{} ({}) is installed'.format(dist.key, dist.version))
    except pkg_resources.DistributionNotFound:
        print('{} is NOT installed'.format(package))
        install(package)
        print('{} was successfully installed.'.format(package))
# Out:
# biopython (1.81) is installed
# pandas (2.2.0) is installed
# numpy (1.26.0) is installed
# matplotlib (3.8.2) is installed
# seaborn (0.13.2) is installed
# xlrd (2.0.1) is installed
# mygene (3.2.2) is installed
# /var/folders/3d/rywrw2f90d13m9fcnt9sf1gw0000gn/T/ipykernel_7487/2437296676.py:3: DeprecationWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html
#   import pkg_resources

# %%
# Import necessary libraries. 
import pandas as pd
import numpy as np
import seaborn as sns
# Out:
# /var/folders/3d/rywrw2f90d13m9fcnt9sf1gw0000gn/T/ipykernel_7487/3903802739.py:2: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %% [markdown]
# ### Loading the Dataset: A First Glimpse into the Zebra Finch's World
#
# With our tools at the ready, let's embark on the initial phase of our exploration. We'll load the dataset containing the read counts from the Zebra Finch RNA-Seq study and begin to unravel the secrets it holds.

# %%
# Loading the RNA-Seq read count data
dataset_path = './dataset/GSE203528_readcount.xls'
df_read_counts = pd.read_csv(dataset_path, sep='\t')


display(df_read_counts.head())
# Out:
#                geneID  HY3  HY4  HY5  HY6  HY8  HY9  HY12  HY13  HY14  ...  \
# 0  ENSTGUG00000008284  145  113  149  121  159  172   133   153   192  ...
# 1  ENSTGUG00000003938   25   18   21   29   22   38    23    34    35  ...
# 2  ENSTGUG00000011987  915  681  938  638  900  749   736   717   657  ...
# 3  ENSTGUG00000017592    5    5    5   14    5    4    22    13    11  ...
# 4  ENSTGUG00000009442  226  211  221  257  202  197   231   201   263  ...
#
#    TN62  TN63  TN64  TN65  TN66  TN67  TN68  TN69  TN70  TN71
# 0   114   111   185   144   134   158   105   143   116   161
# 1    27    52    63    92    31    52    44    53    33    40
# 2   710  1360  1277  1291   554  1225   956  1166   571   936
# 3     3     1     2     5     5     3    11     5    13     2
# 4   271   273   423   226   242   216   365   414   313   316
#
# [5 rows x 135 columns]

# %% [markdown]
# #### Exploring the Zebra Finch RNA-Seq Data
#
# In this RNA-Seq dataset, we delve into the complex world of the Zebra Finch by examining gene expression in three distinct areas of the brain: the hypothalamus, the bed nucleus of the stria terminalis, and the nucleus taeniae. Each of these regions plays a unique role in bird behavior and physiology.
#
# - **The Hypothalamus** (HY samples): This region is crucial for controlling hormones and basic survival functions like feeding, fighting, fleeing, and reproduction.
# - **The Bed Nucleus of the Stria Terminalis** (NST samples): This area is involved in the bird's stress response and emotional behavior.
# - **The Nucleus Taeniae** (TN samples): An area of the brain unique to birds, thought to be involved in social behaviors and possibly song learning.
#
# These regions were likely chosen for their significant roles in behaviors that are crucial for survival and species-specific activities. By analyzing gene expression in these areas, researchers can gain insights into how these regions contribute to the unique behaviors of the Zebra Finch.
#
# **Dataset Breakdown**
#
# Each row in the dataset represents a different gene, identified by a geneID like `ENSTGUG00000008284`. The columns, labeled with codes like `HY3`, `HY4`, `NST3`, etc., correspond to samples from these three brain regions. The numbers are read counts, indicating how often each gene's RNA was detected in the sample. High numbers suggest a gene is very active in that sample.
#
# These numbers are crucial. They tell us how active each gene was in each sample. The higher the number, the more active the gene. By comparing these numbers across different samples, we can get insights into how gene activity varies in different situations or conditions.
#
# <blockquote style="font-family:Arial; color:red; font-size:16px; border-left:0px solid red; padding: 10px;">
#     <strong>Don't forget to answer these questions!</strong>
# </blockquote>
#
# **Questions**
#
# 1. Why do you think the read counts vary between different genes in the same sample? What biological factors might contribute to this variation?
# 2. Can you think of any reasons why the read counts for the same gene might vary between different samples? Consider the experimental design and the nature of biological systems.
# 3. How would you interpret a situation where a gene has a high read count in one sample and a low read count in another? What might this tell us about the gene's role in the Zebra Finch's response to its social environment and the LPS challenge?
#
#
# **Before proceeding, it's essential to ensure you have a foundational understanding of RNA-Seq, the objectives and design of the experiment we're examining, and the significance of each cell in the dataset. Grasping these concepts is crucial for successfully navigating the tasks ahead.**
#
# ---
# **_Your Answer:_**:
#
#
# 1. The variation in read counts between different genes in the same sample can be attributed to inherent biological factors. Key contributors include differences in cell type composition within the sample, variations in gene expression levels, distinct functional roles of genes in specific biological processes, spatial heterogeneity within tissues (even within a specific brain region, there can be spatial heterogeneity in gene expression. Subregions or specific nuclei within the hypothalamus, bed nucleus of the stria terminalis, and nucleus taeniae may have distinct gene expression profiles.), and potential influences of biological variations such as circadian rhythms (approximately 24-hour biological cycles that influence various physiological and behavioral processes in living organisms) or hormonal fluctuations. Technical factors, like RNA extraction and sequencing biases, can also contribute to variability.
#
# 2. Variations in read counts for the same gene across different samples can be attributed to a combination of biological and experimental factors. Biological variability, differences in cell type composition, distinct physiological conditions, genetic variations, and inherent stochasticity in biological processes contribute to differences in gene expression. Additionally, experimental factors like variations in sample processing, RNA extraction, sequencing protocols, and batch effects can introduce technical variability. Careful experimental design, proper normalization techniques, and rigorous statistical analysis are essential to accurately interpret and compare gene expression data across diverse samples.
#
# 3. A high read count in one sample and a low read count in another for a specific gene may indicate differential expression of the gene in response to the bird's social environment and the LPS challenge. This suggests the gene's potential role in these conditions, such as involvement in social interactions. The observed pattern could reveal insights into the molecular mechanisms underlying the Zebra Finch's adaptation to its environment or its response to immune challenges. Further analyses and validation experiments would be needed for a more comprehensive understanding.

# %% [markdown]
# ## Preprocessing and Normalization
#
# In this section, we begin our data analysis by focusing on preprocessing and normalization. Preprocessing involves converting the raw Ensembl gene IDs into more recognizable gene symbols, enhancing the interpretability of our data. Following this, normalization is performed to adjust for variations in sequencing depth and gene length, a crucial step to ensure accurate comparison of gene expression across different samples.

# %% [markdown]
# ### Transforming and Merging the Dataset for Analysis
#
# To facilitate our analysis, we need to restructure the gene expression data so that each row corresponds to a sample, with appropriate labels for social settings and tissue types. This transformation will enable us to apply machine learning techniques and conduct more effective analyses.
#
# The process involves two main steps:
# 1. **Transpose the Gene Expression Data**: Convert the gene expression data so that each row represents a sample and each column corresponds to a gene.
# 2. **Merge with Sample Mapping**: Combine the transposed gene expression data with the `sample_mapping.csv` to add social setting, study group, and tissue type information to each sample.
#
# This approach will create a dataset better suited for exploratory data analysis, clustering, and other statistical methods.

# %%
import pandas as pd

# Load the gene expression data
expression_data = pd.read_csv('./dataset/GSE203528_readcount.xls', sep='\t')

# Transpose the dataframe so that columns become rows and vice versa
transposed_df = expression_data.set_index('geneID').T.reset_index()
transposed_df.rename(columns={'index': 'tissue_id'}, inplace=True)

# Load the sample mapping data
sample_mapping = pd.read_csv('./dataset/sample_mappings.csv')

# Merge the transposed gene expression data with the sample mapping
merged_df = pd.merge(transposed_df, sample_mapping, on='tissue_id')

# Reorder columns to place metadata columns at the front
metadata_columns = ['sample_id', 'social_settting', 'study_group', 'tissue_id']
gene_columns = [col for col in merged_df.columns if col not in metadata_columns]
transformed_df = merged_df[metadata_columns + gene_columns]

# Save the transformed and merged dataset
transformed_df.to_csv('./dataset/transformed_dataset.csv', index=False)

# Display the first few rows of the transformed dataset
display(transformed_df.head())
# Out:
#     sample_id social_settting study_group tissue_id  ENSTGUG00000008284  \
# 0  GSM6175777              NF           L       HY3                 145
# 1  GSM6175779             ISO           S       HY5                 149
# 2  GSM6175780             ISO           L       HY6                 121
# 3  GSM6175781             ISO           L       HY8                 159
# 4  GSM6175782             ISO           L       HY9                 172
#
#    ENSTGUG00000003938  ENSTGUG00000011987  ENSTGUG00000017592  \
# 0                  25                 915                   5
# 1                  21                 938                   5
# 2                  29                 638                  14
# 3                  22                 900                   5
# 4                  38                 749                   4
#
#    ENSTGUG00000009442  ENSTGUG00000009764  ...  ENSTGUG00000010786  \
# 0                 226                  94  ...                 443
# ...

# %% [markdown]
# ### Converting Ensembl IDs to Gene Names (Bonus)
#
# In our dataset, genes are currently identified by Ensembl IDs. While these IDs are precise, they may not be as immediately recognizable as standard gene names. For those interested in working with more familiar gene names, there's a straightforward way to annotate these IDs.
#
# **Steps to Annotate Gene IDs:**
# 1. **Use MyGeneInfo Library**: MyGeneInfo is a powerful tool for gene annotation. It allows you to query a database with Ensembl IDs and retrieve corresponding standard gene names.
# 2. **Query for Zebra Finch Genes**: Given that our study is on Zebra Finch, it's important to use the correct NCBI taxonomy ID (59729) for this species when querying.
# 3. **Merge Results with Original Data**: After obtaining the gene names, you can merge this information back into your dataset, linking each Ensembl ID to its standard gene name.
#
# **Python Implementation**:
# If you wish to perform this annotation, you can use the Python library `mygene`. Initialize a `MyGeneInfo` object, query using your list of Ensembl IDs, and then merge the results with your dataset. This process adds a column for gene names, enhancing the readability and interpretability of your data.
#
# Remember, while this annotation adds clarity, the original Ensembl IDs are crucial for maintaining the accuracy and precision of genomic data.

# %%
import mygene


def annotate_gene_ids(ensembl_ids: list, species_taxid: int):
    """
    Annotate Ensembl gene IDs with corresponding gene symbols.

    Parameters:
    - ensembl_ids (list): List of Ensembl gene IDs to annotate.
    - species_taxid (int): Taxonomic ID of the species for annotation.

    Returns:
    - gene_dict (dict): A dictionary mapping Ensembl gene IDs to their corresponding gene symbols.
    """

    # Convert species_taxid to string
    species_taxid = str(species_taxid)

    # Initialize MyGeneInfo object
    mg = mygene.MyGeneInfo()

    # Query MyGeneInfo database for gene symbols based on Ensembl gene IDs
    try:
        query_result = mg.querymany(ensembl_ids, scopes='ensembl.gene', species=species_taxid, fields='symbol', returnall=True)
    except Exception as e:
        print(f"An error occurred: {e}")
        return {}
    
    # Create a dictionary mapping Ensembl gene IDs to gene symbols
    gene_dict = {}
    for gene in query_result['out']:
        if 'symbol' in gene:
            gene_dict[gene['query']] = gene['symbol']
        else:
            gene_dict[gene['query']] = 'NA'

    return gene_dict


def add_gene_names(df: pd.DataFrame, species_taxid: int):
    """
    Add gene names to DataFrame columns based on Ensembl gene IDs.

    Parameters:
    - df (pd.DataFrame): DataFrame containing columns with Ensembl gene IDs.
    - species_taxid (int): Taxonomic ID of the species for annotation.

    Returns:
    - df_c (pd.DataFrame): A copy of the input DataFrame with columns renamed to include gene names.
    """

    # Extract Ensembl gene IDs from DataFrame columns
    ensembl_ids = [col for col in df.columns if col.startswith('ENST')]

    # Annotate Ensembl gene IDs with gene names using the annotate_gene_ids function
    gene_names = annotate_gene_ids(ensembl_ids, species_taxid)

    # Create a copy of the input DataFrame
    df_c = df.copy()

    # Rename columns to include gene names
    df_c.columns = [f'{col}_{gene_names[col]}' if col in gene_names else col for col in df_c.columns]

    return df_c

# %%
# Example usage of the annotate_gene_ids function
species_taxid = 59729 # Taxonomic ID for Zebra Finch
ensembl_ids = ['ENSTGUG00000008284', 'ENSTGUG00000003938', 'ENSTGUG00000011987',
               'ENSTGUG00000017592', 'ENSTGUG00000009442', 'ENSTGUG00000009764',
               'ENSTGUG00000001666', 'ENSTGUG00000000646', 'ENSTGUG00000004604',
               'ENSTGUG00000000082', 'ENSTGUG00000012724', 'ENSTGUG00000010166']

gene_dict = annotate_gene_ids(ensembl_ids, species_taxid)
print(gene_dict)
# Out:
# 1 input query terms found dup hits:	[('ENSTGUG00000010166', 2)]
# 2 input query terms found no hit:	['ENSTGUG00000008284', 'ENSTGUG00000000646']
# {'ENSTGUG00000008284': 'NA', 'ENSTGUG00000003938': 'VASN', 'ENSTGUG00000011987': 'LAPTM4B', 'ENSTGUG00000017592': 'MIR125-2', 'ENSTGUG00000009442': 'PSMD6', 'ENSTGUG00000009764': 'CD38', 'ENSTGUG00000001666': 'C1GALT1', 'ENSTGUG00000000646': 'NA', 'ENSTGUG00000004604': 'EEIG2', 'ENSTGUG00000000082': 'LNPEP', 'ENSTGUG00000012724': 'LOC100221970', 'ENSTGUG00000010166': 'LOC100229710'}

# %%
# Example usage of the add_gene_names function
species_taxid = 59729 # Taxonomic ID for Zebra Finch
transformed_df = add_gene_names(transformed_df, species_taxid)

transformed_df.head()
# Out:
# 19 input query terms found dup hits:	[('ENSTGUG00000010166', 2), ('ENSTGUG00000011583', 2), ('ENSTGUG00000003913', 2), ('ENSTGUG000000022
# 7586 input query terms found no hit:	['ENSTGUG00000008284', 'ENSTGUG00000015152', 'ENSTGUG00000016201', 'ENSTGUG00000003903', 'ENSTGUG000
#     sample_id social_settting study_group tissue_id  ENSTGUG00000008284_NA  \
# 0  GSM6175777              NF           L       HY3                    145
# 1  GSM6175779             ISO           S       HY5                    149
# 2  GSM6175780             ISO           L       HY6                    121
# 3  GSM6175781             ISO           L       HY8                    159
# 4  GSM6175782             ISO           L       HY9                    172
#
#    ENSTGUG00000003938_VASN  ENSTGUG00000011987_LAPTM4B  \
# 0                       25                         915
# 1                       21                         938
# 2                       29                         638
# ...

# %%
print([col for col in transformed_df.columns if col.endswith('NT-3')])
print([col for col in transformed_df.columns if col.endswith('GDNF')])
print([col for col in transformed_df.columns if col.endswith('CNTF')])
print([col for col in transformed_df.columns if col.endswith('NT4/5')])
print([col for col in transformed_df.columns if col.endswith('IGF-1')])
print([col for col in transformed_df.columns if col.endswith('SHH')])
# Out:
# []
# []
# ['ENSTGUG00000007141_CNTF']
# []
# []
# ['ENSTGUG00000000697_SHH']

# %% [markdown]
# ### Normalization of RNA-Seq Data: Ensuring Accurate Comparisons
#
# Normalization is a crucial step in data analysis. In this context, it corrects for variations in sequencing depth and gene length across samples, enabling accurate comparisons of gene expression levels. Without normalization, differences in read counts could be mistakenly attributed to biological variation instead of technical biases.
#
# **Why Normalize?**
# - **Sequencing Depth Variability**: Different samples might have varying total numbers of reads due to differences in sequencing efficiency. Normalization adjusts for these discrepancies.
# - **Gene Length Bias**: Longer genes tend to have more reads merely due to their size. Normalization methods like TPM (Transcripts Per Million) correct for this by accounting for gene length.
#
# **Normalization Method - Counts Per Million (CPM)**:
# - We'll use the CPM method for its simplicity and effectiveness. CPM normalizes gene expression measurements by dividing the read counts of each gene by the total read counts per million in each sample. This method is suitable for datasets where the focus is on comparing expression patterns rather than quantifying absolute expression levels.
#
# **Implementing CPM in Python**:
# The following Python code demonstrates how to apply CPM normalization to our dataset. It involves calculating the total read counts for each sample, normalizing each gene's read count, and then multiplying by one million.

# %%
import pandas as pd

# Load the dataset
df = pd.read_csv('./dataset/transformed_dataset.csv')

# Function to calculate CPM
# def calculate_cpm(df):
#     total_reads = df.sum(axis=0)
#     cpm = (df / total_reads) * 1e6
#     return cpm


# Function to calculate CPM
def calculate_cpm(df):
    total_reads = df.sum(axis=0)
    cpm = (df / total_reads) * 1e6
    cpm.loc[:, total_reads == 0] = 0
    return cpm

# Apply CPM normalization (excluding metadata columns)
metadata_cols = ['sample_id', 'social_settting', 'study_group', 'tissue_id']
expression_data = df.drop(columns=metadata_cols)
normalized_df = calculate_cpm(expression_data)

# Combine the normalized data with the metadata
normalized_df = pd.concat([df[metadata_cols], normalized_df], axis=1)

# Save the normalized dataset
normalized_df.to_csv('./dataset/normalized_dataset.csv', index=False)

# Display the first few rows of the normalized dataset
display(normalized_df.head())
# Out:
#     sample_id social_settting study_group tissue_id  ENSTGUG00000008284  \
# 0  GSM6175777              NF           L       HY3         7916.143473
# 1  GSM6175779             ISO           S       HY5         8134.519845
# 2  GSM6175780             ISO           L       HY6         6605.885243
# 3  GSM6175781             ISO           L       HY8         8680.460774
# 4  GSM6175782             ISO           L       HY9         9390.183982
#
#    ENSTGUG00000003938  ENSTGUG00000011987  ENSTGUG00000017592  \
# 0         5231.219920         8352.808004         5319.148936
# 1         4394.224733         8562.769298         5319.148936
# 2         6068.215108         5824.143723        14893.617021
# 3         4603.473530         8215.876725         5319.148936
# 4         7951.454279         6837.435186         4255.319149
#
#    ENSTGUG00000009442  ENSTGUG00000009764  ...  ENSTGUG00000010786  \
# 0         6991.276372         7795.007878  ...         9225.899161
# ...

# %% [markdown]
# ### Exploratory Data Analysis: Uncovering Patterns in Gene Expression
#
# Exploratory Data Analysis (EDA) is an essential phase in RNA-Seq data analysis, aimed at visualizing and summarizing data to uncover underlying patterns and trends. For this demonstration, we'll focus on visualizing gene expression differences across study groups ('L' for LPS treatment and 'S' for control) and social settings.
#
# **Key Focus Areas for Our Visualization:**
# 1. **Comparing 'L' and 'S' Study Groups**: This helps us understand the impact of LPS treatment versus control on gene expression.
# 2. **Role of Social Settings**: We'll also explore how different social interactions might influence gene expression patterns.
#
# This demonstration is a starting point for EDA. You are encouraged to explore various aspects of the data through diverse visualizations and analyses.

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Load the normalized dataset
df = pd.read_csv('./dataset/normalized_dataset.csv')

# Select a gene for visualization (example: 'ENSTGUG00000004743', which is Brain-Derived Neurotrophic Factor gene)
selected_gene = 'ENSTGUG00000004743'

# Map the social setting abbreviations to full descriptions
social_setting_map = {
    'ISO': 'Isolated',
    'KFC': 'Known Female Continuous',
    'KF': 'Known Female Reunited',
    'NF': 'Novel Female'
}
df['social_settting'] = df['social_settting'].map(social_setting_map)

# Create a boxplot comparing gene expression across study groups and social settings
plt.figure(figsize=(12, 6))
sns.boxplot(x='social_settting', y=selected_gene, hue='study_group', data=df, palette="Set2")
plt.title('Gene Expression of ' + selected_gene + ' Across Study Groups and Social Settings')
plt.ylabel('Expression Level (CPM)')
plt.xlabel('Social Setting')
plt.legend(title='Study Group')
plt.show()

# %% [markdown]
# **Write down your interpretation of the result of this simple barplot, that displays expression level of `BDNF` gene. First, briefly describe `BDNF` and it's function. Then, write your interpretation about any notable observation you see from the plot**
#
# **_Your Answer_**:
#
# #### BDNF and it's function:
#
#
# BDNF stands for Brain-Derived Neurotrophic Factor. BDNF is a member of the neurotrophin family of proteins and is particularly important for the growth and differentiation of new neurons (nerve cells), as well as the maintenance of existing ones. It is a protein that plays a crucial role in the growth, development, maintenance, and survival of neurons in the brain. As a result it is essential for learning and memory.
# BDNF supports differentiation, maturation, and survival of neurons in the nervous system and shows a neuroprotective effect under adverse conditions, such as glutamatergic stimulation, cerebral ischemia, hypoglycemia, and neurotoxicity.
# (reference:  doi: 10.5114/aoms.2015.56342)
#
#
# #### interpretation of the results:
# if we look at different subjects in different social settings and compare the expression of this gene among treated and control groups within each social setting we can observe in:
#  1. Novel Female: In this social setting, by looking at the median of expression level in each group, it appears the treatment has lowered the expression of BDNF in treatment group. it should also be noted that the range of expression of BDNF between 25th and 75th percentile in treatment group seems to be much smaller. Judging by the protective effect of this factor, lowering its expression in the treatment group might not be ideal. Although to judge the significance of the difference among these two groups, we need to do more rigorous statistical tests.
#
#  2. Isolated: In this social setting, it appears the treatment has lowered the median expression of BDNF in treatment group also. Judging by the protective effect of this factor, this result might not be ideal. Although to judge the significance of the difference between these two groups, we need to do more rigorous statistical tests.
#
#  3. Known Female Reunited: In this social setting, it appears the treatment has increased the median expression of BDNF in treatment group. Judging by the protective effect of this factor, this result might not be a good thing. Although to judge the significance of the difference between these two groups, we need to do more rigorous statistical tests.
#
#  4. Known Female Continuous: In this social setting, it appears the treatment has increased the median expression of BDNF in treatment group. Judging by the protective effect of this factor, this result might not be a good thing. Although to judge the significance of the difference between these two groups, we need to do more rigorous statistical tests.
#
# if we look at different subjects in different treatment groups and compare the expression of this gene among different social settings within each treatment group we can observe in:
#  1. LPS treatment group: It appears the median expression of BDNF is the most in Known Female Reunited social setting which is more than Known Female Continuous social setting and then in these it's more than Novel Female social setting, and lastly the least expression level happeins in Isolated social setting
#
#  2. Contron group: It appears the median expression of BDNF is the most in Known Female Continuous social setting which is more than Novel Female social setting and then in these it's more than Known Female Reunited social setting, and lastly the least expression level happeins in Isolated social setting
#
#
#
#
#
#
#
#
#
# <blockquote style="font-family:Arial; color:red; font-size:16px; border-left:0px solid red; padding: 10px;">
#     <strong>Don't forget to answer this question!</strong>
# </blockquote>

# %% [markdown]
# ### Diverse Visualization Techniques for Gene Expression Data
#
# A comprehensive exploration of gene expression data requires a multifaceted visualization approach. Beyond the boxplot, we will delve into additional techniques that can bring forth deeper insights from our dataset. You are tasked with implementation and interpretation of the results of at least one of the following visualization methods:
#
# - **PCA (Principal Component Analysis)**: This technique reduces the dimensionality of the data and can reveal the underlying structure by capturing the most variation across samples.
# - **t-SNE (t-Distributed Stochastic Neighbor Embedding)**: Particularly useful for visualizing high-dimensional data in a lower-dimensional space, t-SNE can help identify clusters of genes or samples.
# - **UMAP (Uniform Manifold Approximation and Projection)**: Similar to t-SNE, UMAP is useful for visualization and can be faster and more scalable.
#
# In addition to these, consider the following methods to further dissect the dataset:
#
# - **Histograms and Density Plots**: Useful for showing the distribution of gene expression levels within individual samples or conditions.
# - **Boxplots and Violin Plots**: These can summarize the distributions and highlight potential outliers in gene expression levels across samples.
# - **Scatter Plots**: When exploring the relationship between different conditions, scatter plots can be particularly revealing.
# - **Volcano Plots**: Ideal for showcasing differential expression results, highlighting genes with significant fold changes and statistical significance.
#
# Each method will contribute to a holistic view of the dataset, enabling you to uncover patterns and anomalies that may not be apparent through a single visualization strategy.

# %% [markdown]
# #### **Your Turn to Explore**
#
# - **Experiment with Different Genes**: Change the `selected_gene` variable to analyze other genes of interest.
# - **Diverse Visualizations**: Consider using heatmaps, violin plots, or scatter plots for different perspectives.
# - **Incorporate Statistical Analyses**: Complement visual insights with statistical tests to discern if the differences you observe are significant.
#
# Remember, the goal is to thoroughly understand the dataset, paving the way for more in-depth analyses like differential gene expression or clustering.

# %% [markdown]
# ## **My Answer:**

# %% [markdown]
# Before we start with our exploratory analysis, lets see how many samples of each study group and social setting we have:

# %%
df = pd.read_csv('./dataset/normalized_dataset.csv')
counts = np.zeros((df['study_group'].nunique(), df['social_settting'].nunique()))
for i, (study_group, social_setting) in enumerate(df.groupby('study_group')):
    for j, (social_setting, data) in enumerate(social_setting.groupby('social_settting')):
        counts[i, j] = len(data)

# make heatmap
plt.figure(figsize=(10, 6))
sns.heatmap(counts, annot=True, fmt='g', cmap='Blues', xticklabels=social_setting_map.values(), yticklabels=df['study_group'].unique())
plt.title('Sample Distribution Across Study Groups and Social Settings')
plt.xlabel('Social Setting')
plt.ylabel('Study Group')
plt.show()

# %% [markdown]
# #### **Functions for visualization:**
#
# In ```visualize.py``` I have written some functions to visualize the impact of Social Setting and Study Group in expression of a selected gene. These functions include some helper functions for the upstream functions and also the ones that can be called to do the visualizations.
#
# The main functions are:
# - **```make_heatmap(df, gene)```**: Creates a heatmap to visualize gene expression across different study groups and social settings.
#
# - **```make_violin_plot(df, gene)```**: Creates a violin plot to visualize the distribution of gene expression across different study groups and social settings.
#
# - **```make_scatter_plot(df, gene1, gene2)```**:     Creates a scatter plot to visualize the distribution of gene expressions across different study groups and social settings considering the two inputed genes.
#
#
# For these visualization purposes I have chosen violin plots, heatmaps, and scatter plots, since in my opinion these plots better show the expression difference in different groups. These functions are written in a modular manner and all of them are fully documented to hopefully aid you when using them.
#
# Pay attention that in the aformentioned functions, it doesn't matter if you input the gene name or the Ensemble ID of the interested gene. If it can be found in the dataset, it would work flawlessly.
#
# #### **Functions for test statistics:**
# In ```test_statistics.py``` I have written some functions to quantify the impact of Social Setting and Study Group in expression of a selected gene. These functions include some helper functions for the upstream functions and also the ones that can be called to do perform the test statistics.
#
# The main functions are:
# - **```t_test_in_social_setting(df, social_setting, gene)```**: Performs an independent two-sample t-test for a specific gene and social setting among two study groups.
#
# - **```t_test_between_social_settings(df, social_setting1, social_setting2, gene, study_group='both')```**: Performs an independent two-sample t-test between two social settings for a specific gene and study group.
#
# - **```anova_between_social_settings(df, gene, social_settings=['ISO', 'KFC', 'KF', 'NF'], study_group='both')```**: Performs an Analysis of Variance (ANOVA) test for a specific gene across different social settings and study groups.
#
# - **```t_test_between_study_groups(df, gene)```**: Performs an independent two-sample t-test between study groups for a specific gene.
#
# These functions are written in a modular manner and all of them are fully documented to hopefully aid you when using them.
#
# Pay attention that in the aformentioned functions, it doesn't matter if you input the gene name or the Ensemble ID of the interested gene. If it can be found in the dataset, it would work flawlessly.
#
#
# #### **Interesting Genes for This Experiment:**
#
# Some of the genes other than BDNF related to our experiment that might be interesting to visualize include:
# - **Nerve Growth Factor (NGF)**: is an interesting candidate gene to consider in the context of your experiment. NGF is a neurotrophin that plays a crucial role in the growth, survival, and maintenance of neurons.
#
# - **Corticotropin-Releasing Hormone (CRH)**: CRH is a key player in the stress response, and its expression may be influenced by both sickness and social context.
#
# - **Activity-Regulated Cytoskeleton-Associated ProteinArc (Arc)**: Arc is involved in synaptic plasticity and could be relevant for studying how sickness and social interactions impact neural connectivity.
#
# - **Heat Shock Protein 70 (HSP70)**: This molecular chaperone is involved in the cellular response to stress and may play a role in protecting cells during immune challenges.
#
# - **Neurotrophin-3 (NT-3)**: NT-3 is a member of the neurotrophin family, and it plays a role in the development and survival of neurons, especially in the peripheral nervous system.

# %% [markdown]
# ### **Brain-Derived Neurotrophic Factor (BDNF):**
# #### Visualizations related to this gene:

# %%
from visualize import make_heatmap, make_violin_plot
df = pd.read_csv('./dataset/normalized_dataset.csv')
make_heatmap(df, 'BDNF')
make_violin_plot(df, 'BDNF')

# %% [markdown]
# We saw the difference of expression levels of BDNF across different social settings and study groups in the previous part shown as boxplots, in this part we can see the difference shown as a heatmap and violin plots, which in my opinion, is more helpful, and we can see the difference more clearly.
#
#
# Next, we are going to see the statisticall significance of these differences across study groups and social settings by performing test statistics such as T-test and ANOVA.

# %% [markdown]
# #### Test statistics related to this gene:

# %%
from test_statistics import t_test_in_social_setting, t_test_between_social_settings, anova_between_social_settings, t_test_between_study_groups
df = pd.read_csv('./dataset/normalized_dataset.csv')

social_settings = ['NF', 'ISO', 'KF', 'KFC']
for setting in social_settings:
    t_test_in_social_setting(df, setting, 'BDNF')
# Out:
# Social Setting: NF
# Gene: BDNF
# Ensemble ID: ENSTGUG00000004743
# T-Statistic: 0.3156230020942188
# P-Value: 0.7546292445999088
# The difference in means is not statistically significant (p >= 0.05).
# Effect Size: 0.11712356177115561
# The mean of group 'S' is greater than the mean of group 'L'.
# ------------------------------
# Social Setting: ISO
# Gene: BDNF
# Ensemble ID: ENSTGUG00000004743
# T-Statistic: 1.0632284876009934
# P-Value: 0.29539714286869073
# The difference in means is not statistically significant (p >= 0.05).
# Effect Size: 0.33062459028407915
# The mean of group 'S' is greater than the mean of group 'L'.
# ------------------------------
# Social Setting: KF
# Gene: BDNF
# Ensemble ID: ENSTGUG00000004743
# T-Statistic: 0.2838421595753872
# P-Value: 0.7782527330129089
# The difference in means is not statistically significant (p >= 0.05).
# Effect Size: 0.09045429046340576
# The mean of group 'S' is greater than the mean of group 'L'.
# ...

# %% [markdown]
# As you can see, the difference in expression levels of BDNF gene in a specific social setting and between different study groups is not statistically significant.

# %%
anova_between_social_settings(df, 'BDNF')
anova_between_social_settings(df, 'BDNF', study_group='S')
anova_between_social_settings(df, 'BDNF', study_group='L')
# Out:
# Social Settings: ISO, KFC, KF, NF
# Study Group: both
# Gene: BDNF
# Ensemble ID: ENSTGUG00000004743
# F-Statistic: 0.6893528866905089
# P-Value: 0.560161742570495
# The difference in means is not statistically significant (p >= 0.05).
# Effect Size: None
# ------------------------------
# Social Settings: ISO, KFC, KF, NF
# Study Group: S
# Gene: BDNF
# Ensemble ID: ENSTGUG00000004743
# F-Statistic: 0.38550013423363794
# P-Value: 0.763813417285735
# The difference in means is not statistically significant (p >= 0.05).
# Effect Size: None
# ------------------------------
# Social Settings: ISO, KFC, KF, NF
# Study Group: L
# Gene: BDNF
# Ensemble ID: ENSTGUG00000004743
# F-Statistic: 0.5188868408977059
# P-Value: 0.6708668831519647
# The difference in means is not statistically significant (p >= 0.05).
# Effect Size: None
# ------------------------------

# %% [markdown]
# As you can see, the difference in expression levels of BDNF gene across social settings is not statistically significant.

# %%
t_test_between_study_groups(df, 'BDNF')
# Out:
# Gene: BDNF
# Ensemble ID: ENSTGUG00000004743
# T-Statistic: 1.4063031003749782
# P-Value: 0.16203845844097817
# The difference in means is not statistically significant (p >= 0.05).
# Effect Size: 0.22845884953141574
# The mean of study group 'S' is greater than the mean of study group 'L'.
# ------------------------------

# %% [markdown]
# As you can see, the difference in expression levels of BDNF gene between the two social groups not considering the social setting is not statistically significant.

# %% [markdown]
# ### **Nerve Growth Factor (NGF):**
# #### Visualizations related to this gene:

# %%
from visualize import make_heatmap, make_violin_plot
df = pd.read_csv('./dataset/normalized_dataset.csv')
make_heatmap(df, 'NGF')
make_violin_plot(df, 'NGF')

# %% [markdown]
# We can see the difference of NGF gene expression across different social settings and study groups.
#
# In all social settings, apparantly the expression of NGF is higher in LPS treatment study group than the control study group.
#
# There seems to be some outliers in the Isolated and Known Female Reunited social settings and in the LPS treatment study groups.
#
# In my opinion, there is not much difference in gene expression among different social settings.
#
#
#
# Next, we are going to see the statisticall significance of these differences across study groups and social settings by performing test statistics such as T-test and ANOVA.

# %% [markdown]
# #### Test statistics related to this gene:

# %%
from test_statistics import t_test_in_social_setting, t_test_between_social_settings, anova_between_social_settings, t_test_between_study_groups
df = pd.read_csv('./dataset/normalized_dataset.csv')

social_settings = ['NF', 'ISO', 'KF', 'KFC']
for setting in social_settings:
    t_test_in_social_setting(df, setting, 'NGF')
# Out:
# Social Setting: NF
# Gene: NGF
# Ensemble ID: ENSTGUG00000000958
# T-Statistic: -1.179812423135528
# P-Value: 0.24800198942372345
# The difference in means is not statistically significant (p >= 0.05).
# Effect Size: -0.4104422467613765
# The mean of group 'L' is greater than the mean of group 'S'.
# ------------------------------
# Social Setting: ISO
# Gene: NGF
# Ensemble ID: ENSTGUG00000000958
# T-Statistic: -2.014573434196408
# P-Value: 0.052158038301013204
# The difference in means is not statistically significant (p >= 0.05).
# Effect Size: -1.029246687057705
# The mean of group 'L' is greater than the mean of group 'S'.
# ------------------------------
# Social Setting: KF
# Gene: NGF
# Ensemble ID: ENSTGUG00000000958
# T-Statistic: -1.7847190699321547
# P-Value: 0.08323249513869857
# The difference in means is not statistically significant (p >= 0.05).
# Effect Size: -0.9606468673372552
# The mean of group 'L' is greater than the mean of group 'S'.
# ...

# %% [markdown]
# As you can see, the difference in expression levels of NGF gene in a specific social setting and between different study groups is not statistically significant.

# %%
anova_between_social_settings(df, 'NGF')
anova_between_social_settings(df, 'NGF', study_group='S')
anova_between_social_settings(df, 'NGF', study_group='L')
# Out:
# Social Settings: ISO, KFC, KF, NF
# Study Group: both
# Gene: NGF
# Ensemble ID: ENSTGUG00000000958
# F-Statistic: 0.6187580870042285
# P-Value: 0.6041019762292807
# The difference in means is not statistically significant (p >= 0.05).
# Effect Size: None
# ------------------------------
# Social Settings: ISO, KFC, KF, NF
# Study Group: S
# Gene: NGF
# Ensemble ID: ENSTGUG00000000958
# F-Statistic: 0.8622533564248219
# P-Value: 0.46552485735873594
# The difference in means is not statistically significant (p >= 0.05).
# Effect Size: None
# ------------------------------
# Social Settings: ISO, KFC, KF, NF
# Study Group: L
# Gene: NGF
# Ensemble ID: ENSTGUG00000000958
# F-Statistic: 0.1984093539563608
# P-Value: 0.8970819447358395
# The difference in means is not statistically significant (p >= 0.05).
# Effect Size: None
# ------------------------------

# %% [markdown]
# As you can see, the difference in expression levels of NGF gene across social settings is not statistically significant.

# %%
t_test_between_study_groups(df, 'NGF')
# Out:
# Gene: NGF
# Ensemble ID: ENSTGUG00000000958
# T-Statistic: -3.4757371884886434
# P-Value: 0.0006945621264680453
# The difference in means is statistically significant (p < 0.05).
# Effect Size: -0.7708531311829349
# The mean of study group 'L' is greater than the mean of study group 'S'.
# ------------------------------

# %% [markdown]
# As you can see, the difference in expression levels of NGF gene between the two social groups not considering the social setting is statistically significant.

# %% [markdown]
# ### **Corticotropin-Releasing Hormone (CRH):**
# #### Visualizations related to this gene:

# %%
from visualize import make_heatmap, make_violin_plot
df = pd.read_csv('./dataset/normalized_dataset.csv')
make_heatmap(df, 'CRH')
make_violin_plot(df, 'CRH')

# %% [markdown]
# We can see the difference of CRH gene expression across different social settings and study groups.
#
# In all social settings, apparantly the expression of CRH is lower in LPS treatment study group than the control study group.
#
# There seems to be some outliers in the Isolated social settings and in thelcontron study groups.
#
#
# In my opinion, there is not much difference in gene expression among different social settings.
#
# Another thing to note from the violin plot, is that the distribution of gene expression in novel female and known female continous groups seems to be more of a bimodal distribution than a guassian normal distribution.
#
# Next, we are going to see the statisticall significance of these differences across study groups and social settings by performing test statistics such as T-test and ANOVA.

# %% [markdown]
# #### Test statistics related to this gene:

# %%
from test_statistics import t_test_in_social_setting, t_test_between_social_settings, anova_between_social_settings, t_test_between_study_groups
df = pd.read_csv('./dataset/normalized_dataset.csv')

social_settings = ['NF', 'ISO', 'KF', 'KFC']
for setting in social_settings:
    t_test_in_social_setting(df, setting, 'CRH')
# Out:
# Social Setting: NF
# Gene: CRH
# Ensemble ID: ENSTGUG00000011277
# T-Statistic: 1.659908163752001
# P-Value: 0.10809328546323818
# The difference in means is not statistically significant (p >= 0.05).
# Effect Size: 0.5686335749730486
# The mean of group 'S' is greater than the mean of group 'L'.
# ------------------------------
# Social Setting: ISO
# Gene: CRH
# Ensemble ID: ENSTGUG00000011277
# T-Statistic: 1.479384010645369
# P-Value: 0.14852136514028613
# The difference in means is not statistically significant (p >= 0.05).
# Effect Size: 0.3910491008006819
# The mean of group 'S' is greater than the mean of group 'L'.
# ------------------------------
# Social Setting: KF
# Gene: CRH
# Ensemble ID: ENSTGUG00000011277
# T-Statistic: 0.5383859469059138
# P-Value: 0.5938181149872799
# The difference in means is not statistically significant (p >= 0.05).
# Effect Size: 0.15091541928497176
# The mean of group 'S' is greater than the mean of group 'L'.
# ...

# %% [markdown]
# As you can see, the difference in expression levels of CRH gene in a specific social setting and between different study groups is not statistically significant.

# %%
anova_between_social_settings(df, 'CRH')
anova_between_social_settings(df, 'CRH', study_group='S')
anova_between_social_settings(df, 'CRH', study_group='L')
# Out:
# Social Settings: ISO, KFC, KF, NF
# Study Group: both
# Gene: CRH
# Ensemble ID: ENSTGUG00000011277
# F-Statistic: 1.1001751324824451
# P-Value: 0.3516817041748164
# The difference in means is not statistically significant (p >= 0.05).
# Effect Size: None
# ------------------------------
# Social Settings: ISO, KFC, KF, NF
# Study Group: S
# Gene: CRH
# Ensemble ID: ENSTGUG00000011277
# F-Statistic: 0.2109144211219598
# P-Value: 0.8884735565270074
# The difference in means is not statistically significant (p >= 0.05).
# Effect Size: None
# ------------------------------
# Social Settings: ISO, KFC, KF, NF
# Study Group: L
# Gene: CRH
# Ensemble ID: ENSTGUG00000011277
# F-Statistic: 1.8785836205384463
# P-Value: 0.1426418047019636
# The difference in means is not statistically significant (p >= 0.05).
# Effect Size: None
# ------------------------------

# %% [markdown]
# As you can see, the difference in expression levels of CRH gene across social settings is not statistically significant.

# %%
t_test_between_study_groups(df, 'CRH')
# Out:
# Gene: CRH
# Ensemble ID: ENSTGUG00000011277
# T-Statistic: 1.9740444529790808
# P-Value: 0.050513307747788276
# The difference in means is not statistically significant (p >= 0.05).
# Effect Size: 0.3008959829053184
# The mean of study group 'S' is greater than the mean of study group 'L'.
# ------------------------------

# %% [markdown]
# As you can see, the difference in expression levels of NGF gene between the two social groups not considering the social setting is statistically significant, but it's pretty close to be considered significant.

# %% [markdown]
# ### **Activity-Regulated Cytoskeleton-Associated ProteinArc (Arc):**
# #### Visualizations related to this gene:

# %%
from visualize import make_heatmap, make_violin_plot
df = pd.read_csv('./dataset/normalized_dataset.csv')
make_heatmap(df, 'Arc')
make_violin_plot(df, 'Arc')
# Out:
# An error occurred: ('Connection aborted.', ConnectionResetError(54, 'Connection reset by peer'))

# %% [markdown]
# We can see the difference of Arc gene expression across different social settings and study groups.
#
# In all social settings, apparantly the expression of Arc is lower in LPS treatment study group than the control study group.
#
# There seems to be some outliers in the Isolated and Known Female Reunited social settings and in the control study groups.
#
#
# In my opinion, there is not much difference in gene expression among different social settings.
#
#
# Next, we are going to see the statisticall significance of these differences across study groups and social settings by performing test statistics such as T-test and ANOVA.

# %% [markdown]
# #### Test statistics related to this gene:

# %%
from test_statistics import t_test_in_social_setting, t_test_between_social_settings, anova_between_social_settings, t_test_between_study_groups
df = pd.read_csv('./dataset/normalized_dataset.csv')

social_settings = ['NF', 'ISO', 'KF', 'KFC']
for setting in social_settings:
    t_test_in_social_setting(df, setting, 'Arc')
# Out:
# Social Setting: NF
# Gene: ARC
# Ensemble ID: ENSTGUG00000012727
# T-Statistic: 0.7006121877892415
# P-Value: 0.48932659119549127
# The difference in means is not statistically significant (p >= 0.05).
# Effect Size: 0.23952139704751663
# The mean of group 'S' is greater than the mean of group 'L'.
# ------------------------------
# Social Setting: ISO
# Gene: ARC
# Ensemble ID: ENSTGUG00000012727
# T-Statistic: 1.7049986358712355
# P-Value: 0.09759310737667609
# The difference in means is not statistically significant (p >= 0.05).
# Effect Size: 0.43754356116615034
# The mean of group 'S' is greater than the mean of group 'L'.
# ------------------------------
# Social Setting: KF
# Gene: ARC
# Ensemble ID: ENSTGUG00000012727
# T-Statistic: 1.0599325245213695
# P-Value: 0.2966472523160672
# The difference in means is not statistically significant (p >= 0.05).
# Effect Size: 0.2869488310819531
# The mean of group 'S' is greater than the mean of group 'L'.
# ...

# %% [markdown]
# As you can see, the difference in expression levels of Arc gene in a specific social setting and between different study groups is not statistically significant.

# %%
anova_between_social_settings(df, 'Arc')
anova_between_social_settings(df, 'Arc', study_group='S')
anova_between_social_settings(df, 'Arc', study_group='L')
# Out:
# Social Settings: ISO, KFC, KF, NF
# Study Group: both
# Gene: ARC
# Ensemble ID: ENSTGUG00000012727
# F-Statistic: 1.5690876893334327
# P-Value: 0.2001200455533391
# The difference in means is not statistically significant (p >= 0.05).
# Effect Size: None
# ------------------------------
# Social Settings: ISO, KFC, KF, NF
# Study Group: S
# Gene: ARC
# Ensemble ID: ENSTGUG00000012727
# F-Statistic: 0.5476130198527133
# P-Value: 0.6516127405748888
# The difference in means is not statistically significant (p >= 0.05).
# Effect Size: None
# ------------------------------
# Social Settings: ISO, KFC, KF, NF
# Study Group: L
# Gene: ARC
# Ensemble ID: ENSTGUG00000012727
# F-Statistic: 1.7542022872952632
# P-Value: 0.16541791617957974
# The difference in means is not statistically significant (p >= 0.05).
# Effect Size: None
# ------------------------------

# %% [markdown]
# As you can see, the difference in expression levels of Arc gene across social settings is not statistically significant.

# %%
t_test_between_study_groups(df, 'Arc')
# Out:
# Gene: ARC
# Ensemble ID: ENSTGUG00000012727
# T-Statistic: 2.388109495577182
# P-Value: 0.018384993875176683
# The difference in means is statistically significant (p < 0.05).
# Effect Size: 0.3466990739710982
# The mean of study group 'S' is greater than the mean of study group 'L'.
# ------------------------------

# %% [markdown]
# As you can see, the difference in expression levels of Arc gene between the two social groups not considering the social setting is statistically significant.

# %% [markdown]
# ### **Heat Shock Protein 70 (HSP70):**
# #### Visualizations related to this gene:

# %%
from visualize import make_heatmap, make_violin_plot
df = pd.read_csv('./dataset/normalized_dataset.csv')
make_heatmap(df, 'HSP70')
make_violin_plot(df, 'HSP70')

# %% [markdown]
# We can see the difference of HSP70 gene expression across different social settings and study groups.
#
#
#
# In Novel Female ocial setting, the expression of HSP70 seems to be higher in LPS treatment study group than the control study group.
#
# In Isolated social setting, the expression of HSP70 seems to be lower in LPS treatment study group than the control study group.
#
# In Known Female Reunited social setting, the expression of HSP70 seems to be similar in LPS treatment study group and the control study group, but the variance of this amount seems to be higher in the control study group than the LPS treatment study group.
#
# In Known Female Continuous social setting, the expression of HSP70 seems to be similar in LPS treatment study group and the control study group
#
# There seems to be some outliers in the Isolated and Known Female Reunited social settings and in the control study groups.
#
#
# In my opinion, there is not much difference in gene expression among different social settings.
#
#
# Next, we are going to see the statisticall significance of these differences across study groups and social settings by performing test statistics such as T-test and ANOVA.

# %% [markdown]
# #### Test statistics related to this gene:

# %%
from test_statistics import t_test_in_social_setting, t_test_between_social_settings, anova_between_social_settings, t_test_between_study_groups
df = pd.read_csv('./dataset/normalized_dataset.csv')

social_settings = ['NF', 'ISO', 'KF', 'KFC']
for setting in social_settings:
    t_test_in_social_setting(df, setting, 'HSP70')
# Out:
# Social Setting: NF
# Gene: ST13
# Ensemble ID: ENSTGUG00000010046
# T-Statistic: -1.8707114123746973
# P-Value: 0.0718710490402447
# The difference in means is not statistically significant (p >= 0.05).
# Effect Size: -0.7714688029734802
# The mean of group 'L' is greater than the mean of group 'S'.
# ------------------------------
# Social Setting: ISO
# Gene: ST13
# Ensemble ID: ENSTGUG00000010046
# T-Statistic: 4.0505234899723455
# P-Value: 0.0002914360519314247
# The difference in means is statistically significant (p < 0.05).
# Effect Size: 1.1540159321924448
# The mean of group 'S' is greater than the mean of group 'L'.
# ------------------------------
# Social Setting: KF
# Gene: ST13
# Ensemble ID: ENSTGUG00000010046
# T-Statistic: 0.9093561986182729
# P-Value: 0.3695636192519762
# The difference in means is not statistically significant (p >= 0.05).
# Effect Size: 0.24515205656168046
# The mean of group 'S' is greater than the mean of group 'L'.
# ...

# %% [markdown]
# As you can see, the difference in expression levels of HSP70 gene in all but Isolated social setting and between different study groups is not statistically significant. But in isolated social setting the difference of expression level of HSP70 different study groups seems to be significant.

# %%
anova_between_social_settings(df, 'HSP70')
anova_between_social_settings(df, 'HSP70', study_group='S')
anova_between_social_settings(df, 'HSP70', study_group='L')
# Out:
# Social Settings: ISO, KFC, KF, NF
# Study Group: both
# Gene: ST13
# Ensemble ID: ENSTGUG00000010046
# F-Statistic: 1.1355021054173782
# P-Value: 0.337369088699931
# The difference in means is not statistically significant (p >= 0.05).
# Effect Size: None
# ------------------------------
# Social Settings: ISO, KFC, KF, NF
# Study Group: S
# Gene: ST13
# Ensemble ID: ENSTGUG00000010046
# F-Statistic: 4.367984461207043
# P-Value: 0.007446782758484995
# The difference in means is statistically significant (p < 0.05).
# Effect Size: None
# ------------------------------
# Social Settings: ISO, KFC, KF, NF
# Study Group: L
# Gene: ST13
# Ensemble ID: ENSTGUG00000010046
# F-Statistic: 1.9192278016637512
# P-Value: 0.13589069354426977
# The difference in means is not statistically significant (p >= 0.05).
# Effect Size: None
# ------------------------------

# %% [markdown]
# As you can see, the difference in expression levels of HSP70 gene across social settings in control study group seems to be statistically significant.

# %%
t_test_between_study_groups(df, 'HSP70')
# Out:
# Gene: ST13
# Ensemble ID: ENSTGUG00000010046
# T-Statistic: 1.55471808227527
# P-Value: 0.12246320836414981
# The difference in means is not statistically significant (p >= 0.05).
# Effect Size: 0.23545726957950175
# The mean of study group 'S' is greater than the mean of study group 'L'.
# ------------------------------

# %% [markdown]
# As you can see, the difference in expression levels of HSP70 gene between the two social groups not considering the social setting is not statistically significant.

# %% [markdown]
# ### **Neurotrophin-3 (NT-3):**
# #### Visualizations related to this gene:

# %%
from visualize import make_heatmap, make_violin_plot
df = pd.read_csv('./dataset/normalized_dataset.csv')
make_heatmap(df, 'NT-3')
make_violin_plot(df, 'NT-3')

# %% [markdown]
# We can see the difference of NT-3 gene expression across different social settings and study groups.
#
#
#
# In Novel Female and Known Female Continuous social settings, the expression of NT-3 similar in LPS treatment study group and the control study group.
#
# In Isolated and Known Female Reunited social setting, the expression of NT-3 seems to be lower in LPS treatment study group than the control study group.
#
#
# In my opinion, there is not much difference in gene expression among different social settings.
#
#
# Next, we are going to see the statisticall significance of these differences across study groups and social settings by performing test statistics such as T-test and ANOVA.

# %% [markdown]
# #### Test statistics related to this gene:

# %%
from test_statistics import t_test_in_social_setting, t_test_between_social_settings, anova_between_social_settings, t_test_between_study_groups
df = pd.read_csv('./dataset/normalized_dataset.csv')

social_settings = ['NF', 'ISO', 'KF', 'KFC']
for setting in social_settings:
    t_test_in_social_setting(df, setting, 'NT-3')
# Out:
# Social Setting: NF
# Gene: NTRK3
# Ensemble ID: ENSTGUG00000008364
# T-Statistic: -0.07072921273359645
# P-Value: 0.9441160371945665
# The difference in means is not statistically significant (p >= 0.05).
# Effect Size: -0.029698875361682513
# The mean of group 'L' is greater than the mean of group 'S'.
# ------------------------------
# Social Setting: ISO
# Gene: NTRK3
# Ensemble ID: ENSTGUG00000008364
# T-Statistic: 0.9047909237147895
# P-Value: 0.3721346620833802
# The difference in means is not statistically significant (p >= 0.05).
# Effect Size: 0.312760403968576
# The mean of group 'S' is greater than the mean of group 'L'.
# ------------------------------
# Social Setting: KF
# Gene: NTRK3
# Ensemble ID: ENSTGUG00000008364
# T-Statistic: -0.24337746659856588
# P-Value: 0.8091754565896843
# The difference in means is not statistically significant (p >= 0.05).
# Effect Size: -0.07313859244906759
# The mean of group 'L' is greater than the mean of group 'S'.
# ...

# %% [markdown]
# As you can see, the difference in expression levels of NT-3 gene in a specific social setting and between different study groups is not statistically significant.

# %%
anova_between_social_settings(df, 'NT-3')
anova_between_social_settings(df, 'NT-3', study_group='S')
anova_between_social_settings(df, 'NT-3', study_group='L')
# Out:
# Social Settings: ISO, KFC, KF, NF
# Study Group: both
# Gene: NTRK3
# Ensemble ID: ENSTGUG00000008364
# F-Statistic: 1.4463848181535854
# P-Value: 0.23244641167776897
# The difference in means is not statistically significant (p >= 0.05).
# Effect Size: None
# ------------------------------
# Social Settings: ISO, KFC, KF, NF
# Study Group: S
# Gene: NTRK3
# Ensemble ID: ENSTGUG00000008364
# F-Statistic: 0.33412571414750925
# P-Value: 0.8006917002936333
# The difference in means is not statistically significant (p >= 0.05).
# Effect Size: None
# ------------------------------
# Social Settings: ISO, KFC, KF, NF
# Study Group: L
# Gene: NTRK3
# Ensemble ID: ENSTGUG00000008364
# F-Statistic: 1.2795035620292101
# P-Value: 0.2894326584672004
# The difference in means is not statistically significant (p >= 0.05).
# Effect Size: None
# ------------------------------

# %% [markdown]
# As you can see, the difference in expression levels of NT-3 gene across social settings is not statistically significant.

# %%
t_test_between_study_groups(df, 'NT-3')
# Out:
# Gene: NTRK3
# Ensemble ID: ENSTGUG00000008364
# T-Statistic: 0.1308208541281697
# P-Value: 0.8961208192265847
# The difference in means is not statistically significant (p >= 0.05).
# Effect Size: 0.023641552821074826
# The mean of study group 'S' is greater than the mean of study group 'L'.
# ------------------------------

# %% [markdown]
# As you can see, the difference in expression levels of NT-3 gene between the two social groups not considering the social setting is not statistically significant.

# %% [markdown]
# #### Making scatter plot considering two genes:
#
# As we saw before, the difference of gene expression among two study groups were only significant in NGF and Arc gene. So knowing that, lets make a scatter plot and set the x and y axis as the expression of these two genes;

# %%
from visualize import make_scatter_plot
df = pd.read_csv('./dataset/normalized_dataset.csv')
make_scatter_plot(df, 'Arc', 'NGF')

# %% [markdown]
# As you can see, from this graph we cannot separate different social groups and social setting very clrealy. Maybe it's a good idea to make separate plots for differente social settings and see if the difference between social groups is obvious.

# %%
for social_setting in df['social_settting'].unique():
    df_c = df[df['social_settting'] == social_setting]
    make_scatter_plot(df_c, 'Arc', 'NGF')

# %% [markdown]
# As you can see, the difference between differnt study groups is more clear now.

# %% [markdown]
# ### Reflecting on Visualizations to Extract Key Insights
#
# As we have navigated through different visualization strategies, it's time to consolidate the knowledge you've gained. Reflect on the insights each visualization has provided:
#
# - **What trends have you observed in the distribution of gene expression levels?**
# - **How do the expression levels compare when you look across different conditions or samples?**
# - **From the heatmap, were you able to detect any consistent patterns of expression, such as upregulation or downregulation of certain genes?**
# - **Did any outliers or unusual expression patterns emerge? What might these suggest about certain genes or the overall data quality?**
#
# Write down your observations and hypotheses. Discuss and note down your interpretations as they will be valuable for the upcoming stages of differential gene expression analysis.
#
# **_Your Answer_**:
#
# The answers are given during the making of plots and performing the test statitics.

# %% [markdown]
# ---

# %% [markdown]
# ### Differential Gene Expression Analysis
#
# After exploring the general patterns in our dataset, the next step is Differential Gene Expression (DGE) analysis. This process will help us identify genes whose expression levels significantly differ across treatments or social settings.
#
# #### Addressing High Dimensionality in RNA-Seq Data for Differential Gene Expression Analysis
#
# In RNA-Seq data, high dimensionality (a large number of genes) presents several analytical challenges. This complexity can obscure meaningful biological insights and impact the statistical power of our analyses.
#
# **Challenges of High Dimensionality**:
# 1. **Statistical Power Loss**: With too many variables (genes), the risk of finding false positives increases, known as the 'multiple testing problem'.
# 2. **Overfitting Risk**: High-dimensional data can lead to models that are too complex, capturing noise rather than true underlying patterns.
# 3. **Computational Intensity**: Analyzing thousands of genes simultaneously demands significant computational resources and time.
# 4. **Interpretation Difficulty**: It becomes challenging to interpret results and extract biologically meaningful conclusions from a vast pool of data.
#
# **Addressing These Challenges**:
# 1. **Dimensionality Reduction**: Techniques like PCA (Principal Component Analysis) and t-SNE (t-Distributed Stochastic Neighbor Embedding) help in reducing the number of dimensions, making the data more manageable and revealing hidden structures.
# 2. **RNA-Seq Specific Tools for DGE Analysis**: Tools like DESeq2 and edgeR (available in Python through rpy2 or similar interfaces) are designed to handle high-dimensional data. They offer:
#    - **Normalization and Variance Stabilization**: Tailored for RNA-Seq data, ensuring fair comparisons across samples.
#    - **FDR Control**: Implement procedures to adjust for multiple comparisons, reducing false positives.
#    - **Biological Variance Modeling**: Consider the biological variability, enhancing the reliability of results.
#
# **Python Implementation**:
# - In python environments, the use of R-based tools like DESeq2 or edgeR is possible through interfaces such as `rpy2`. This approach allows you to leverage the strengths of these tools while working within a Python framework. However, as stated multiple times in this project, you have freedom to choose alternative method for any task, as long as it makes sense.

# %%
### TODO ###
# Placeholder for PCA Analysis.

from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt

# Note: Before applying PCA, it's important to standardize the data
# Example: Standardize the gene expression data (excluding metadata columns)

# Load your expression data here
df = pd.read_csv('./dataset/normalized_dataset.csv')
metadata_cols = ['sample_id', 'social_settting', 'study_group', 'tissue_id']
expression_data = df.drop(columns=metadata_cols)



# Standardize the data
scaler = StandardScaler()
expression_scaled = scaler.fit_transform(expression_data)


# Apply PCA
pca = PCA(n_components=2)
principal_components = pca.fit_transform(expression_scaled)

# Explained variance ratio
explained_variance_ratio = pca.explained_variance_ratio_
cumulative_explained_variance = explained_variance_ratio.cumsum()

# Plot the PCA results
plt.figure(figsize=(10, 8))
plt.scatter(principal_components[:, 0], principal_components[:, 1])
plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')
plt.title('PCA of Gene Expression Data')
plt.show()

# Tip: Explore the variance ratio to decide on the number of components
# Tip: Use annotations or different colors to highlight groups based on treatment or social settings

# %%
import pandas as pd
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt

# Load your expression data here
df = pd.read_csv('./dataset/normalized_dataset.csv')
metadata_cols = ['sample_id', 'social_settting', 'study_group', 'tissue_id']
expression_data = df.drop(columns=metadata_cols)



# Standardize the data
scaler = StandardScaler()
expression_scaled = scaler.fit_transform(expression_data)

# Apply PCA
pca = PCA()
principal_components = pca.fit_transform(expression_scaled)

# Explained variance ratio
explained_variance_ratio = pca.explained_variance_ratio_
cumulative_explained_variance = explained_variance_ratio.cumsum()

# Plot explained variance
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
plt.bar(range(1, len(explained_variance_ratio) + 1), explained_variance_ratio, alpha=0.8)
plt.xlabel('Principal Component')
plt.ylabel('Explained Variance Ratio')
plt.title('Explained Variance Ratio by Principal Component')

# Plot cumulative explained variance
plt.subplot(1, 2, 2)
plt.plot(range(1, len(cumulative_explained_variance) + 1), cumulative_explained_variance, marker='o', linestyle='--', color='r')
plt.xlabel('Number of Principal Components')
plt.ylabel('Cumulative Explained Variance')
plt.title('Cumulative Explained Variance')

plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10, 8))
for group in df['study_group'].unique():
    indices = df['study_group'] == group
    plt.scatter(principal_components[indices, 0], principal_components[indices, 1], label=group)

plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')
plt.title('PCA of Gene Expression Data')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(10, 8))
for group in df['social_settting'].unique():
    indices = df['social_settting'] == group
    plt.scatter(principal_components[indices, 0], principal_components[indices, 1], label=group)

plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')
plt.title('PCA of Gene Expression Data')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(10, 8))

social_settings = df['social_settting'].unique()
study_groups = df['study_group'].unique()

for social_setting in social_settings:
    for study_group in study_groups:
        indices = (df['social_settting'] == social_setting) & (df['study_group'] == study_group)
        plt.scatter(
            principal_components[indices, 0],
            principal_components[indices, 1],
            label=f'Social Setting: {social_setting}, Study Group: {study_group}'
        )

plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')
plt.title('PCA of Gene Expression Data')
plt.legend()
plt.show()

# %%
fig = plt.figure(figsize=(10, 8))
ax = fig.add_subplot(111, projection='3d')

for group in df['study_group'].unique():
    indices = df['study_group'] == group
    ax.scatter(principal_components[indices, 0], principal_components[indices, 1], principal_components[indices, 2], label=group)

ax.set_xlabel('Principal Component 1')
ax.set_ylabel('Principal Component 2')
ax.set_zlabel('Principal Component 3')
ax.set_title('3D PCA of Gene Expression Data by Study Group')
ax.legend()
plt.show()

# %%
fig = plt.figure(figsize=(10, 8))
ax = fig.add_subplot(111, projection='3d')

for group in df['social_settting'].unique():
    indices = df['social_settting'] == group
    ax.scatter(principal_components[indices, 0], principal_components[indices, 1], principal_components[indices, 2], label=group)

ax.set_xlabel('Principal Component 1')
ax.set_ylabel('Principal Component 2')
ax.set_zlabel('Principal Component 3')
ax.set_title('3D PCA of Gene Expression Data by Social Setting')
ax.legend()
plt.show()

# %%
fig = plt.figure(figsize=(10, 8))
ax = fig.add_subplot(111, projection='3d')

social_settings = df['social_settting'].unique()
study_groups = df['study_group'].unique()

for social_setting in social_settings:
    for study_group in study_groups:
        indices = (df['social_settting'] == social_setting) & (df['study_group'] == study_group)
        ax.scatter(
            principal_components[indices, 0],
            principal_components[indices, 1],
            principal_components[indices, 2],
            label=f'Social Setting: {social_setting}, Study Group: {study_group}'
        )

ax.set_xlabel('Principal Component 1')
ax.set_ylabel('Principal Component 2')
ax.set_zlabel('Principal Component 3')
ax.set_title('3D PCA of Gene Expression Data by Social Setting and Study Group')
ax.legend()
plt.show()

# %%
### TODO ###
# Placeholder for using a common RNA-Seq analysis tool from Python

import subprocess

# Example: Using DESeq2 via R for Differential Gene Expression Analysis
# DESeq2 is a popular tool for RNA-Seq data, particularly useful for identifying differentially expressed genes

# Define the paths and necessary arguments
r_script_path = 'path/to/deseq2_analysis.R'
input_file_path = 'path/to/normalized_dataset.csv'  # CSV file path
output_file_path = 'path/to/deseq2_output.csv'      # Path to save the DESeq2 output

# Construct the command to run the R script using subprocess
command = ['Rscript', r_script_path, input_file_path, output_file_path]

# Run the command
subprocess.run(command)

# Tips and Hints:
# - Ensure that R and DESeq2 are installed in your environment.
# - The R script should be written to take input and output file paths as arguments.
# - The script should handle the reading of the CSV file, applying DESeq2, and writing the results back to a CSV.
# - In the R script, consider using additional metadata columns (like 'study_group', 'social_settting') as part of the DESeq2 design formula to account for these factors in the analysis.
# - You can capture the output and errors from the subprocess to check if the script ran successfully.
# - For Python users not familiar with R, consider using Python alternatives or interfaces such as rpy2 to work with DESeq2.
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /Users/sina/Sem-4/bioinformatics/project/task_3/tasks/the-songbird-study/SongBirdStudy.ipynb Cell 107 line 1
#      <a href='vscode-notebook-cell:/Users/sina/Sem-4/bioinformatics/project/task_3/tasks/the-songbird-study/SongBirdStudy.ipynb#Y211sZmlsZQ%3D%3D?line=14'>15</a> command = ['Rscript', r_script_path, input_file_path, output_file_path]
#      <a href='vscode-notebook-cell:/Users/sina/Sem-4/bioinformatics/project/task_3/tasks/the-songbird-study/SongBirdStudy.ipynb#Y211sZmlsZQ%3D%3D?line=16'>17</a> # Run the command
# ---> <a href='vscode-notebook-cell:/Users/sina/Sem-4/bioinformatics/project/task_3/tasks/the-songbird-study/SongBirdStudy.ipynb#Y211sZmlsZQ%3D%3D?line=17'>18</a> subprocess.run(command)
# ...

# %% [markdown]
# ### Identifying Differentially Expressed Genes (DEGs)
#
# The core of our RNA-Seq analysis lies in identifying Differentially Expressed Genes (DEGs) between different conditions, such as LPS treatment vs control, and across social settings. Identifying DEGs helps in pinpointing specific genes that are responsive to our experimental treatments.
#
# **Freedom in Methodology**:
# - You are free to choose your preferred method or tool for DEG analysis. Whether it's DESeq2, edgeR, or any other method, the key is to reliably identify genes that show statistically significant differences in expression.
#
# ### Interpreting the Findings
#
# After identifying DEGs, the next crucial step is interpreting these findings. This involves understanding the biological functions and pathways these genes are involved in.
#
# **Functional Annotation and Pathway Analysis**:
# - Utilize databases like Gene Ontology (GO), Kyoto Encyclopedia of Genes and Genomes (KEGG), or DAVID for functional annotation.
# - Interpret the roles of these genes in biological processes, cellular components, and molecular functions.
#
# ### Visualization for Insightful Understanding
#
# A critical aspect of this phase is visualization. Effective visualizations can provide profound insights into the data and help in communicating your findings.
#
# **Visualizations Can Include**:
# - Heatmaps of DEGs.
# - Volcano plots showing the significance vs. fold-change.
# - Pathway diagrams to illustrate the affected biological pathways.
#
# ### Emphasis on Interpretation and Informative Visualization
#
# Remember, the ultimate goal is to not only identify DEGs but to also understand their biological significance and visually represent this information in an insightful and informative manner. Your interpretations and visualizations are crucial for translating raw data into meaningful biological insights.

# %%
### TODO ###
# Placeholder for DEG Analysis, Interpretation, and Visualization

# Step 1: DEG Analysis
# Use your chosen tool/method to identify DEGs
# Example: results = DESeq2_DEG_analysis(input_file)

# Step 2: Functional Annotation
# Utilize online databases or tools for gene annotation
# Example: annotated_genes = annotate_genes(results['gene_id'])

# Step 3: Pathway Analysis
# Map the DEGs to biological pathways
# Example: pathways = map_to_pathways(annotated_genes)

# Step 4: Visualization
# Create insightful visualizations of the DEGs
# Example: create_heatmap(results)
# Example: create_volcano_plot(results)
# Example: plot_pathways(pathways)

# Remember to interpret your findings in the context of the biological questions and hypotheses you are exploring.
# Consider the biological significance of the DEGs and their roles in the context of your study.
